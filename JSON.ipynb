# %%
import requests 
  
# Making a GET request 
r = requests.get('https://restcountries.com/v3.1/all') 
  
# check status code for response received 
# success code - 200 
print(r) 
  
# print content of request 
print(r.content)
# Out:
# <Response [200]>
# b'[{"name":{"common":"Moldova","official":"Republic of Moldova","nativeName":{"ron":{"official":"Republica Moldova","common":"Moldova"}}},"tld":[".md"],"cca2":"MD","ccn3":"498","cca3":"MDA","cioc":"MDA","independent":true,"status":"officially-assigned","unMember":true,"currencies":{"MDL":{"name":"Moldovan leu","symbol":"L"}},"idd":{"root":"+3","suffixes":["73"]},"capital":["Chi\xc8\x99in\xc4\x83u"],"altSpellings":["MD","Moldova, Republic of","Republic of Moldova","Republica Moldova"],"region":"Europe","subregion":"Eastern Europe","languages":{"ron":"Romanian"},"translations":{"ara":{"official":"\xd8\xac\xd9\x85\xd9\x87\xd9\x88\xd8\xb1\xd9\x8a\xd8\xa9 \xd9\x85\xd9\x88\xd9\x84\xd8\xaf\xd9\x88\xda\xa4\xd8\xa7","common":"\xd9\x85\xd9\x88\xd9\x84\xd8\xaf\xd9\x88\xda\xa4\xd8\xa7"},"bre":{"official":"Republik Moldova","common":"Moldova"},"ces":{"official":"Moldavsk\xc3\xa1 republika","common":"Moldavsko"},"cym":{"official":"Republic of Moldova","common":"Moldova"},"deu":{"official":"Republik Moldau","common":"Moldawien"},"est":{"official":"Moldova Vabariik","common":"Moldova"},"fin":{"official":"Moldovan tasavalta","common":"Moldova"},"fra":{"official":"R\xc3\xa9publique de Moldavie","common":"Moldavie"},"hrv":{"official":"Moldavija","common":"Moldova"},"hun":{"official":"Moldovai K\xc3\xb6zt\xc3\xa1rsas\xc3\xa1g","common":"Moldova"},"ita":{"official":"Repubblica di Moldova","common":"Moldavia"},"jpn":{"official":"\xe3\x83\xa2\xe3\x83\xab\xe3\x83\x89\xe3\x83\x90\xe5\x85\xb1\xe5\x92\x8c\xe5\x9b\xbd","common":"\xe3\x83\xa2\xe3\x83\xab\xe3\x83\x89\xe3\x83\x90\xe5\x85\xb1\xe5\x92\x8c\xe5\x9b\xbd"},"kor":{"official":"\xeb\xaa\xb0\xeb\x8f\x84\xeb\xb0\x94 \xea\xb3\xb5\xed\x99\x94\xea\xb5\xad","common":"\xeb\xaa\xb0\xeb\x8f\x84\xeb\xb0\x94"},"nld":{"official":"Republiek Moldavi\xc3\xab","common":"Moldavi\xc3\xab"},"per":{"official":"\xd8\xac\xd9\x85\xd9\x87\xd9\x88\xd8\xb1\xdb\x8c \xd9\x85\xd9\x88\xd9\x84\xd8\xaf\xd8\xa7\xd9\x88\xdb\x8c","common":"\xd9\x85\xd9\x88\xd9\x84\xd8\xaf\xd8\xa7\xd9\x88\xdb\x8c"},"pol":{"official":"Republika Mo\xc5\x82dawii","common":"Mo\xc5\x82dawia"},"por":{"official":"Rep\xc3\xbablica da Mold\xc3\xa1via","common":"Mold\xc3\xa1via"},"rus":{"official":"\xd0\x9c\xd0\xbe\xd0\xbb\xd0\xb4\xd0\xbe\xd0\xb2\xd0\xb0","common":"\xd0\x9c\xd0\xbe\xd0\xbb\xd0\xb4\xd0\xb0\xd0\xb2\xd0\xb8\xd1\x8f"},"slk":{"official":"Moldavsk\xc3\xa1 republika","common":"Moldavsko"},"spa":{"official":"Rep\xc3\xbablica de Moldova","common":"Moldavia"},"srp":{"official":"\xd0\xa0\xd0\xb5\xd0\xbf\xd1\x83\xd0\xb1\xd0\xbb\xd0\xb8\xd0\xba\xd0\xb0 \xd0\x9c\xd0\xbe\xd0\xbb\xd0\xb4\xd0\xb0\xd0\xb2\xd0\xb8\xd1\x98\xd0\xb0","common":"\xd0\x9c\xd0\xbe\xd0\xbb\xd0\xb4\xd0\xb0\xd0\xb2\xd0\xb8\xd1\x98\xd0\xb0"},"swe":{"official":"Republiken Moldavien","common":"Moldavien"},"tur":{"official":"Moldova Cumhuriyeti","common":"Moldova"},"urd":{"official":"\xd8\xac\xd9\x85\xdb\x81\xd9\x88\xd8\xb1\xdb\x8c\xdb\x81 \xd9\x85\xd8\xa7\xd9\x84\xd8\xaf\xd9\x88\xd9\x88\xd8\xa7","common":"\xd9\x85\xd8\xa7\xd9\x84\xd8\xaf\xd9\x88\xd9\x88\xd8\xa7"},"zho":{"official":"\xe6\x91\xa9\xe5\xb0\x94\xe5\xa4\x9a\xe7\x93\xa6\xe5\x85\xb1\xe5\x92\x8c\xe5\x9b\xbd","common":"\xe6\x91\xa9\xe5\xb0\x94\xe5\xa4\x9a\xe7\x93\xa6"}},"latlng":[47.0,29.0],"landlocked":true,"borders":["ROU","UKR"],"area":33846.0,"demonyms":{"eng":{"f":"Moldovan","m":"Moldovan"},"fra":{"f":"Moldave","m":"Moldave"}},"flag":"\\uD83C\\uDDF2\\uD83C\\uDDE9","maps":{"googleMaps":"https://goo.gl/maps/JjmyUuULujnDeFPf7","openStreetMaps":"https://www.openstreetmap.org/relation/58974"},"population":2617820,"gini":{"2018":25.7},"fifa":"MDA","car":{"signs":["MD"],"side":"right"},"timezones":["UTC+02:00"],"continents":["Europe"],"flags":{"png":"https://flagcdn.com/w320/md.png","svg":"https://flagcdn.com/md.svg","alt":"The flag of Moldova is composed of three equal vertical bands of blue, yellow and red, with the national coat of arms centered in the yellow band."},"coatOfArms":{"png":"https://mainfacts.com/media/images/coats_of_arm ...

# %%
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    # Printing JSON data using 'countries_data' variable
    print(countries_data)
else:
    print("Failed to fetch data.")
# Out:
# [{'name': {'common': 'Moldova', 'official': 'Republic of Moldova', 'nativeName': {'ron': {'official': 'Republica Moldova', 'common': 'Moldova'}}}, 'tld': ['.md'], 'cca2': 'MD', 'ccn3': '498', 'cca3': 'MDA', 'cioc': 'MDA', 'independent': True, 'status': 'officially-assigned', 'unMember': True, 'currencies': {'MDL': {'name': 'Moldovan leu', 'symbol': 'L'}}, 'idd': {'root': '+3', 'suffixes': ['73']}, 'capital': ['Chișinău'], 'altSpellings': ['MD', 'Moldova, Republic of', 'Republic of Moldova', 'Republica Moldova'], 'region': 'Europe', 'subregion': 'Eastern Europe', 'languages': {'ron': 'Romanian'}, 'translations': {'ara': {'official': 'جمهورية مولدوڤا', 'common': 'مولدوڤا'}, 'bre': {'official': 'Republik Moldova', 'common': 'Moldova'}, 'ces': {'official': 'Moldavská republika', 'common': 'Moldavsko'}, 'cym': {'official': 'Republic of Moldova', 'common': 'Moldova'}, 'deu': {'official': 'Republik Moldau', 'common': 'Moldawien'}, 'est': {'official': 'Moldova Vabariik', 'common': 'Moldova'}, 'fin': {'official': 'Moldovan tasavalta', 'common': 'Moldova'}, 'fra': {'official': 'République de Moldavie', 'common': 'Moldavie'}, 'hrv': {'official': 'Moldavija', 'common': 'Moldova'}, 'hun': {'official': 'Moldovai Köztársaság', 'common': 'Moldova'}, 'ita': {'official': 'Repubblica di Moldova', 'common': 'Moldavia'}, 'jpn': {'official': 'モルドバ共和国', 'common': 'モルドバ共和国'}, 'kor': {'official': '몰도바 공화국', 'common': '몰도바'}, 'nld': {'official': 'Republiek Moldavië', 'common': 'Moldavië'}, 'per': {'official': 'جمهوری مولداوی', 'common': 'مولداوی'}, 'pol': {'official': 'Republika Mołdawii', 'common': 'Mołdawia'}, 'por': {'official': 'República da Moldávia', 'common': 'Moldávia'}, 'rus': {'official': 'Молдова', 'common': 'Молдавия'}, 'slk': {'official': 'Moldavská republika', 'common': 'Moldavsko'}, 'spa': {'official': 'República de Moldova', 'common': 'Moldavia'}, 'srp': {'official': 'Република Молдавија', 'common': 'Молдавија'}, 'swe': {'official': 'Republiken Moldavien', 'common': 'Moldavien'}, 'tur': {'official': 'Moldova Cumhuriyeti', 'common': 'Moldova'}, 'urd': {'official': 'جمہوریہ مالدووا', 'common': 'مالدووا'}, 'zho': {'official': '摩尔多瓦共和国', 'common': '摩尔多瓦'}}, 'latlng': [47.0, 29.0], 'landlocked': True, 'borders': ['ROU', 'UKR'], 'area': 33846.0, 'demonyms': {'eng': {'f': 'Moldovan', 'm': 'Moldovan'}, 'fra': {'f': 'Moldave', 'm': 'Moldave'}}, 'flag': '🇲🇩', 'maps': {'googleMaps': 'https://goo.gl/maps/JjmyUuULujnDeFPf7', 'openStreetMaps': 'https://www.openstreetmap.org/relation/58974'}, 'population': 2617820, 'gini': {'2018': 25.7}, 'fifa': 'MDA', 'car': {'signs': ['MD'], 'side': 'right'}, 'timezones': ['UTC+02:00'], 'continents': ['Europe'], 'flags': {'png': 'https://flagcdn.com/w320/md.png', 'svg': 'https://flagcdn.com/md.svg', 'alt': 'The flag of Moldova is composed of three equal vertical bands of blue, yellow and red, with the national coat of arms centered in the yellow band.'}, 'coatOfArms': {'png': 'https://mainfacts.com/media/images/coats_of_arms/md.png', 'svg': 'https://mainfacts.com/media/images/coats_of_arms/md.svg'}, 'startOfWeek': 'monday', 'capitalInfo': {'latlng': [47.01, 28.9]}, 'postalCode': {'format': 'MD-####', 'regex': '^(?:MD)*(\\d{4})$'}}, {'name': {'common': 'United States', 'official': 'United States of America', 'nativeName': {'eng': {'official': 'United States of America', 'common': 'United States'}}}, 'tld': ['.us'], 'cca2': 'US', 'ccn3': '840', 'cca3': 'USA', 'cioc': 'USA', 'independent': True, 'status': 'officially-assigned', 'unMember': True, 'currencies': {'USD': {'name': 'United States dollar', 'symbol': '$'}}, 'idd': {'root': '+1', 'suffixes': ['201', '202', '203', '205', '206', '207', '208', '209', '210', '212', '213', '214', '215', '216', '217', '218', '219', '220', '224', '225', '227', '228', '229', '231', '234', '239', '240', '248', '251', '252', '253', '254', '256', '260', '262', '267', '269', '270', '272', '274', '276', '281', '283', '301', '302', '303', '304', '305', '307', '308', '309', '310', '312', '31 ...

# %%
import requests

def fetch_countries_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Example usage
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    # Now you can work with the 'countries_data' variable, which contains the JSON data
    print(countries_data)
else:
    print("Failed to fetch data.")
import requests

def fetch_countries_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
# Out:
# [{'name': {'common': 'Moldova', 'official': 'Republic of Moldova', 'nativeName': {'ron': {'official': 'Republica Moldova', 'common': 'Moldova'}}}, 'tld': ['.md'], 'cca2': 'MD', 'ccn3': '498', 'cca3': 'MDA', 'cioc': 'MDA', 'independent': True, 'status': 'officially-assigned', 'unMember': True, 'currencies': {'MDL': {'name': 'Moldovan leu', 'symbol': 'L'}}, 'idd': {'root': '+3', 'suffixes': ['73']}, 'capital': ['Chișinău'], 'altSpellings': ['MD', 'Moldova, Republic of', 'Republic of Moldova', 'Republica Moldova'], 'region': 'Europe', 'subregion': 'Eastern Europe', 'languages': {'ron': 'Romanian'}, 'translations': {'ara': {'official': 'جمهورية مولدوڤا', 'common': 'مولدوڤا'}, 'bre': {'official': 'Republik Moldova', 'common': 'Moldova'}, 'ces': {'official': 'Moldavská republika', 'common': 'Moldavsko'}, 'cym': {'official': 'Republic of Moldova', 'common': 'Moldova'}, 'deu': {'official': 'Republik Moldau', 'common': 'Moldawien'}, 'est': {'official': 'Moldova Vabariik', 'common': 'Moldova'}, 'fin': {'official': 'Moldovan tasavalta', 'common': 'Moldova'}, 'fra': {'official': 'République de Moldavie', 'common': 'Moldavie'}, 'hrv': {'official': 'Moldavija', 'common': 'Moldova'}, 'hun': {'official': 'Moldovai Köztársaság', 'common': 'Moldova'}, 'ita': {'official': 'Repubblica di Moldova', 'common': 'Moldavia'}, 'jpn': {'official': 'モルドバ共和国', 'common': 'モルドバ共和国'}, 'kor': {'official': '몰도바 공화국', 'common': '몰도바'}, 'nld': {'official': 'Republiek Moldavië', 'common': 'Moldavië'}, 'per': {'official': 'جمهوری مولداوی', 'common': 'مولداوی'}, 'pol': {'official': 'Republika Mołdawii', 'common': 'Mołdawia'}, 'por': {'official': 'República da Moldávia', 'common': 'Moldávia'}, 'rus': {'official': 'Молдова', 'common': 'Молдавия'}, 'slk': {'official': 'Moldavská republika', 'common': 'Moldavsko'}, 'spa': {'official': 'República de Moldova', 'common': 'Moldavia'}, 'srp': {'official': 'Република Молдавија', 'common': 'Молдавија'}, 'swe': {'official': 'Republiken Moldavien', 'common': 'Moldavien'}, 'tur': {'official': 'Moldova Cumhuriyeti', 'common': 'Moldova'}, 'urd': {'official': 'جمہوریہ مالدووا', 'common': 'مالدووا'}, 'zho': {'official': '摩尔多瓦共和国', 'common': '摩尔多瓦'}}, 'latlng': [47.0, 29.0], 'landlocked': True, 'borders': ['ROU', 'UKR'], 'area': 33846.0, 'demonyms': {'eng': {'f': 'Moldovan', 'm': 'Moldovan'}, 'fra': {'f': 'Moldave', 'm': 'Moldave'}}, 'flag': '🇲🇩', 'maps': {'googleMaps': 'https://goo.gl/maps/JjmyUuULujnDeFPf7', 'openStreetMaps': 'https://www.openstreetmap.org/relation/58974'}, 'population': 2617820, 'gini': {'2018': 25.7}, 'fifa': 'MDA', 'car': {'signs': ['MD'], 'side': 'right'}, 'timezones': ['UTC+02:00'], 'continents': ['Europe'], 'flags': {'png': 'https://flagcdn.com/w320/md.png', 'svg': 'https://flagcdn.com/md.svg', 'alt': 'The flag of Moldova is composed of three equal vertical bands of blue, yellow and red, with the national coat of arms centered in the yellow band.'}, 'coatOfArms': {'png': 'https://mainfacts.com/media/images/coats_of_arms/md.png', 'svg': 'https://mainfacts.com/media/images/coats_of_arms/md.svg'}, 'startOfWeek': 'monday', 'capitalInfo': {'latlng': [47.01, 28.9]}, 'postalCode': {'format': 'MD-####', 'regex': '^(?:MD)*(\\d{4})$'}}, {'name': {'common': 'United States', 'official': 'United States of America', 'nativeName': {'eng': {'official': 'United States of America', 'common': 'United States'}}}, 'tld': ['.us'], 'cca2': 'US', 'ccn3': '840', 'cca3': 'USA', 'cioc': 'USA', 'independent': True, 'status': 'officially-assigned', 'unMember': True, 'currencies': {'USD': {'name': 'United States dollar', 'symbol': '$'}}, 'idd': {'root': '+1', 'suffixes': ['201', '202', '203', '205', '206', '207', '208', '209', '210', '212', '213', '214', '215', '216', '217', '218', '219', '220', '224', '225', '227', '228', '229', '231', '234', '239', '240', '248', '251', '252', '253', '254', '256', '260', '262', '267', '269', '270', '272', '274', '276', '281', '283', '301', '302', '303', '304', '305', '307', '308', '309', '310', '312', '31 ...

# %%
#Fetching Country, Currencies & currency symbol
def display_country_info(country_data):
    for country in country_data:
        name = country.get('name', {}).get('common', 'N/A')
        currencies = country.get('currencies', {})
        
        if currencies:
            print(f"Country: {name}")
            print("Currencies:")
            
            for currency_code, currency_info in currencies.items():
                currency_name = currency_info.get('name', 'N/A')
                currency_symbol = currency_info.get('symbol', 'N/A')
                
                print(f"  - Currency Code: {currency_code}")
                print(f"    Currency Name: {currency_name}")
                print(f"    Currency Symbol: {currency_symbol}")
            
            print("\n")

url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    display_country_info(countries_data)
else:
    print("Failed to fetch data.")
import requests

def fetch_countries_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
# Out:
# Country: Moldova
# Currencies:
#   - Currency Code: MDL
#     Currency Name: Moldovan leu
#     Currency Symbol: L
#
#
# Country: United States
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Mayotte
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Nauru
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#
#
# Country: Mozambique
# Currencies:
#   - Currency Code: MZN
#     Currency Name: Mozambican metical
#     Currency Symbol: MT
#
#
# Country: Brazil
# Currencies:
#   - Currency Code: BRL
#     Currency Name: Brazilian real
#     Currency Symbol: R$
#
#
# Country: Cape Verde
# Currencies:
#   - Currency Code: CVE
#     Currency Name: Cape Verdean escudo
#     Currency Symbol: Esc
#
#
# Country: Equatorial Guinea
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Albania
# Currencies:
#   - Currency Code: ALL
#     Currency Name: Albanian lek
#     Currency Symbol: L
#
#
# Country: United States Virgin Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Niue
# Currencies:
#   - Currency Code: NZD
#     Currency Name: New Zealand dollar
#     Currency Symbol: $
#
#
# Country: Palau
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Nigeria
# Currencies:
#   - Currency Code: NGN
#     Currency Name: Nigerian naira
#     Currency Symbol: ₦
#
#
# Country: British Virgin Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Gambia
# Currencies:
#   - Currency Code: GMD
#     Currency Name: dalasi
#     Currency Symbol: D
#
#
# Country: Somalia
# Currencies:
#   - Currency Code: SOS
#     Currency Name: Somali shilling
#     Currency Symbol: Sh
#
#
# Country: Yemen
# Currencies:
#   - Currency Code: YER
#     Currency Name: Yemeni rial
#     Currency Symbol: ﷼
#
#
# Country: Malaysia
# Currencies:
#   - Currency Code: MYR
#     Currency Name: Malaysian ringgit
#     Currency Symbol: RM
#
#
# Country: Dominica
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: United Kingdom
# Currencies:
#   - Currency Code: GBP
#     Currency Name: British pound
#     Currency Symbol: £
#
#
# Country: Madagascar
# Currencies:
#   - Currency Code: MGA
#     Currency Name: Malagasy ariary
#     Currency Symbol: Ar
#
#
# Country: Western Sahara
# Currencies:
#   - Currency Code: DZD
#     Currency Name: Algerian dinar
#     Currency Symbol: دج
#   - Currency Code: MAD
#     Currency Name: Moroccan dirham
#     Currency Symbol: DH
#   - Currency Code: MRU
#     Currency Name: Mauritanian ouguiya
#     Currency Symbol: UM
#
#
# Country: Cyprus
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Antigua and Barbuda
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Ireland
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Paraguay
# Currencies:
#   - Currency Code: PYG
#     Currency Name: Paraguayan guaraní
#     Currency Symbol: ₲
#
#
# Country: Sri Lanka
# Currencies:
#   - Currency Code: LKR
#     Currency Name: Sri Lankan rupee
#     Currency Symbol: Rs  රු
#
#
# Country: South Africa
# Currencies:
#   - Currency Code: ZAR
#     Currency Name: South African rand
#     Currency Symbol: R
#
#
# Country: Kuwait
# Currencies:
#   - Currency Code: KWD
#     Currency Name: Kuwaiti dinar
#     Currency Symbol: د.ك
#
#
# Country: Algeria
# Currencies:
#   - Currency Code: DZD
#     Currency Name: Algerian dinar
#     Currency Symbol: د.ج
#
#
# Country: Croatia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Martinique
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Sierra Leone
# Currencies:
#   - Currency Code: SLL
#     Currency Name: Sierra Leonean leone
#     Currency Symbol: Le
#
#
# Country: Northern Mariana Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Rwanda
# Currencies:
#   - Currency Code: RWF
#     Currency Name: Rwandan franc
#     Currency Symbol: Fr
#
#
# Country: Syria
# Currencies:
#   - Currency Code: SYP
#     Currency Name: Syrian pound
#     Currency Symbol: £
#
#
# Country: Saint Vincent and the Grenadines
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Kosovo
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Saint Lucia
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Honduras
# Currencies:
#   - Currency Code: HNL
#     Currency Name: Honduran lempira
#     Currency Symbol: L
#
#
# Country: Jordan
# Currencies:
#   - Currency Code: JOD
#     Currency Name: Jordanian dinar
#     Currency Symbol: د.ا
#
#
# Country: Tuvalu
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#   - Currency Code: TVD
#     Currency Name: Tuvaluan dollar
#     Currency Symbol: $
#
#
# Country: Nepal
# Currencies:
#   - Currency Code: NPR
#     Currency Name: Nepalese rupee
#     Currency Symbol: ₨
#
#
# Country: Liberia
# Currencies:
#   - Currency Code: LRD
#     Currency Name: Liberian dollar
#     Currency Symbol: $
#
#
# Country: Austria
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Guernsey
# Currencies:
#   - Currency Code: GBP
#     Currency Name: British pound
#     Currency Symbol: £
#   - Currency Code: GGP
#     Currency Name: Guernsey pound
#     Currency Symbol: £
#
#
# Country: Central African Republic
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Mauritania
# Currencies:
#   - Currency Code: MRU
#     Currency Name: Mauritanian ouguiya
#     Currency Symbol: UM
#
#
# Country: Djibouti
# Currencies:
#   - Currency Code: DJF
#     Currency Name: Djiboutian franc
#     Currency Symbol: Fr
#
#
# Country: Fiji
# Currencies:
#   - Currency Code: FJD
#     Currency Name: Fijian dollar
#     Currency Symbol: $
#
#
# Country: Norway
# Currencies:
#   - Currency Code: NOK
#     Currency Name: Norwegian krone
#     Currency Symbol: kr
#
#
# Country: Latvia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Falkland Islands
# Currencies:
#   - Currency Code: FKP
#     Currency Name: Falkland Islands pound
#     Currency Symbol: £
#
#
# Country: Kazakhstan
# Currencies:
#   - Currency Code: KZT
#     Currency Name: Kazakhstani tenge
#     Currency Symbol: ₸
#
#
# Country: Åland Islands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Turkmenistan
# Currencies:
#   - Currency Code: TMT
#     Currency Name: Turkmenistan manat
#     Currency Symbol: m
#
#
# Country: Cocos (Keeling) Islands
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#
#
# Country: Bulgaria
# Currencies:
#   - Currency Code: BGN
#     Currency Name: Bulgarian lev
#     Currency Symbol: лв
#
#
# Country: Tokelau
# Currencies:
#   - Currency Code: NZD
#     Currency Name: New Zealand dollar
#     Currency Symbol: $
#
#
# Country: New Caledonia
# Currencies:
#   - Currency Code: XPF
#     Currency Name: CFP franc
#     Currency Symbol: ₣
#
#
# Country: Barbados
# Currencies:
#   - Currency Code: BBD
#     Currency Name: Barbadian dollar
#     Currency Symbol: $
#
#
# Country: São Tomé and Príncipe
# Currencies:
#   - Currency Code: STN
#     Currency Name: São Tomé and Príncipe dobra
#     Currency Symbol: Db
#
#
# Country: Brunei
# Currencies:
#   - Currency Code: BND
#     Currency Name: Brunei dollar
#     Currency Symbol: $
#   - Currency Code: SGD
#     Currency Name: Singapore dollar
#     Currency Symbol: $
#
#
# Country: Bhutan
# Currencies:
#   - Currency Code: BTN
#     Currency Name: Bhutanese ngultrum
#     Currency Symbol: Nu.
#   - Currency Code: INR
#     Currency Name: Indian rupee
#     Currency Symbol: ₹
#
#
# Country: Cameroon
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Argentina
# Currencies:
#   - Currency Code: ARS
#     Currency Name: Argentine peso
#     Currency Symbol: $
#
#
# Country: Azerbaijan
# Currencies:
#   - Currency Code: AZN
#     Currency Name: Azerbaijani manat
#     Currency Symbol: ₼
#
#
# Country: Mexico
# Currencies:
#   - Currency Code: MXN
#     Currency Name: Mexican peso
#     Currency Symbol: $
#
#
# Country: Morocco
# Currencies:
#   - Currency Code: MAD
#     Currency Name: Moroccan dirham
#     Currency Symbol: د.م.
#
#
# Country: Guatemala
# Currencies:
#   - Currency Code: GTQ
#     Currency Name: Guatemalan quetzal
#     Currency Symbol: Q
#
#
# Country: Kenya
# Currencies:
#   - Currency Code: KES
#     Currency Name: Kenyan shilling
#     Currency Symbol: Sh
#
#
# Country: Malta
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Czechia
# Currencies:
#   - Currency Code: CZK
#     Currency Name: Czech koruna
#     Currency Symbol: Kč
#
#
# Country: Gibraltar
# Currencies:
#   - Currency Code: GIP
#     Currency Name: Gibraltar pound
#     Currency Symbol: £
#
#
# Country: Aruba
# Currencies:
#   - Currency Code: AWG
#     Currency Name: Aruban florin
#     Currency Symbol: ƒ
#
#
# Country: Saint Barthélemy
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Monaco
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: United Arab Emirates
# Currencies:
#   - Currency Code: AED
#     Currency Name: United Arab Emirates dirham
#     Currency Symbol: د.إ
#
#
# Country: South Sudan
# Currencies:
#   - Currency Code: SSP
#     Currency Name: South Sudanese pound
#     Currency Symbol: £
#
#
# Country: Puerto Rico
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: El Salvador
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: France
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Niger
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Ivory Coast
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: South Georgia
# Currencies:
#   - Currency Code: SHP
#     Currency Name: Saint Helena pound
#     Currency Symbol: £
#
#
# Country: Botswana
# Currencies:
#   - Currency Code: BWP
#     Currency Name: Botswana pula
#     Currency Symbol: P
#
#
# Country: British Indian Ocean Territory
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Uzbekistan
# Currencies:
#   - Currency Code: UZS
#     Currency Name: Uzbekistani soʻm
#     Currency Symbol: so'm
#
#
# Country: Tunisia
# Currencies:
#   - Currency Code: TND
#     Currency Name: Tunisian dinar
#     Currency Symbol: د.ت
#
#
# Country: Hong Kong
# Currencies:
#   - Currency Code: HKD
#     Currency Name: Hong Kong dollar
#     Currency Symbol: $
#
#
# Country: North Macedonia
# Currencies:
#   - Currency Code: MKD
#     Currency Name: denar
#     Currency Symbol: den
#
#
# Country: Suriname
# Currencies:
#   - Currency Code: SRD
#     Currency Name: Surinamese dollar
#     Currency Symbol: $
#
#
# Country: Belgium
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: American Samoa
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Solomon Islands
# Currencies:
#   - Currency Code: SBD
#     Currency Name: Solomon Islands dollar
#     Currency Symbol: $
#
#
# Country: Ukraine
# Currencies:
#   - Currency Code: UAH
#     Currency Name: Ukrainian hryvnia
#     Currency Symbol: ₴
#
#
# Country: Finland
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Burkina Faso
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Bosnia and Herzegovina
# Currencies:
#   - Currency Code: BAM
#     Currency Name: Bosnia and Herzegovina convertible mark
#     Currency Symbol: N/A
#
#
# Country: Iran
# Currencies:
#   - Currency Code: IRR
#     Currency Name: Iranian rial
#     Currency Symbol: ﷼
#
#
# Country: Cuba
# Currencies:
#   - Currency Code: CUC
#     Currency Name: Cuban convertible peso
#     Currency Symbol: $
#   - Currency Code: CUP
#     Currency Name: Cuban peso
#     Currency Symbol: $
#
#
# Country: Eritrea
# Currencies:
#   - Currency Code: ERN
#     Currency Name: Eritrean nakfa
#     Currency Symbol: Nfk
#
#
# Country: Slovakia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Lithuania
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Saint Martin
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Pitcairn Islands
# Currencies:
#   - Currency Code: NZD
#     Currency Name: New Zealand dollar
#     Currency Symbol: $
#
#
# Country: Guinea-Bissau
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Montserrat
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Turkey
# Currencies:
#   - Currency Code: TRY
#     Currency Name: Turkish lira
#     Currency Symbol: ₺
#
#
# Country: Philippines
# Currencies:
#   - Currency Code: PHP
#     Currency Name: Philippine peso
#     Currency Symbol: ₱
#
#
# Country: Vanuatu
# Currencies:
#   - Currency Code: VUV
#     Currency Name: Vanuatu vatu
#     Currency Symbol: Vt
#
#
# Country: Bolivia
# Currencies:
#   - Currency Code: BOB
#     Currency Name: Bolivian boliviano
#     Currency Symbol: Bs.
#
#
# Country: Saint Kitts and Nevis
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Romania
# Currencies:
#   - Currency Code: RON
#     Currency Name: Romanian leu
#     Currency Symbol: lei
#
#
# Country: Cambodia
# Currencies:
#   - Currency Code: KHR
#     Currency Name: Cambodian riel
#     Currency Symbol: ៛
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Zimbabwe
# Currencies:
#   - Currency Code: ZWL
#     Currency Name: Zimbabwean dollar
#     Currency Symbol: $
#
#
# Country: Jersey
# Currencies:
#   - Currency Code: GBP
#     Currency Name: British pound
#     Currency Symbol: £
#   - Currency Code: JEP
#     Currency Name: Jersey pound
#     Currency Symbol: £
#
#
# Country: Kyrgyzstan
# Currencies:
#   - Currency Code: KGS
#     Currency Name: Kyrgyzstani som
#     Currency Symbol: с
#
#
# Country: Caribbean Netherlands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Guyana
# Currencies:
#   - Currency Code: GYD
#     Currency Name: Guyanese dollar
#     Currency Symbol: $
#
#
# Country: United States Minor Outlying Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Armenia
# Currencies:
#   - Currency Code: AMD
#     Currency Name: Armenian dram
#     Currency Symbol: ֏
#
#
# Country: Lebanon
# Currencies:
#   - Currency Code: LBP
#     Currency Name: Lebanese pound
#     Currency Symbol: ل.ل
#
#
# Country: Montenegro
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Greenland
# Currencies:
#   - Currency Code: DKK
#     Currency Name: krone
#     Currency Symbol: kr.
#
#
# Country: Papua New Guinea
# Currencies:
#   - Currency Code: PGK
#     Currency Name: Papua New Guinean kina
#     Currency Symbol: K
#
#
# Country: Zambia
# Currencies:
#   - Currency Code: ZMW
#     Currency Name: Zambian kwacha
#     Currency Symbol: ZK
#
#
# Country: Trinidad and Tobago
# Currencies:
#   - Currency Code: TTD
#     Currency Name: Trinidad and Tobago dollar
#     Currency Symbol: $
#
#
# Country: French Southern and Antarctic Lands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Peru
# Currencies:
#   - Currency Code: PEN
#     Currency Name: Peruvian sol
#     Currency Symbol: S/
#
#
# Country: Sweden
# Currencies:
#   - Currency Code: SEK
#     Currency Name: Swedish krona
#     Currency Symbol: kr
#
#
# Country: Sudan
# Currencies:
#   - Currency Code: SDG
#     Currency Name: Sudanese pound
#     Currency Symbol: N/A
#
#
# Country: Saint Pierre and Miquelon
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Oman
# Currencies:
#   - Currency Code: OMR
#     Currency Name: Omani rial
#     Currency Symbol: ر.ع.
#
#
# Country: India
# Currencies:
#   - Currency Code: INR
#     Currency Name: Indian rupee
#     Currency Symbol: ₹
#
#
# Country: Taiwan
# Currencies:
#   - Currency Code: TWD
#     Currency Name: New Taiwan dollar
#     Currency Symbol: $
#
#
# Country: Mongolia
# Currencies:
#   - Currency Code: MNT
#     Currency Name: Mongolian tögrög
#     Currency Symbol: ₮
#
#
# Country: Senegal
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Tanzania
# Currencies:
#   - Currency Code: TZS
#     Currency Name: Tanzanian shilling
#     Currency Symbol: Sh
#
#
# Country: Canada
# Currencies:
#   - Currency Code: CAD
#     Currency Name: Canadian dollar
#     Currency Symbol: $
#
#
# Country: Costa Rica
# Currencies:
#   - Currency Code: CRC
#     Currency Name: Costa Rican colón
#     Currency Symbol: ₡
#
#
# Country: China
# Currencies:
#   - Currency Code: CNY
#     Currency Name: Chinese yuan
#     Currency Symbol: ¥
#
#
# Country: Colombia
# Currencies:
#   - Currency Code: COP
#     Currency Name: Colombian peso
#     Currency Symbol: $
#
#
# Country: Myanmar
# Currencies:
#   - Currency Code: MMK
#     Currency Name: Burmese kyat
#     Currency Symbol: Ks
#
#
# Country: Russia
# Currencies:
#   - Currency Code: RUB
#     Currency Name: Russian ruble
#     Currency Symbol: ₽
#
#
# Country: North Korea
# Currencies:
#   - Currency Code: KPW
#     Currency Name: North Korean won
#     Currency Symbol: ₩
#
#
# Country: Cayman Islands
# Currencies:
#   - Currency Code: KYD
#     Currency Name: Cayman Islands dollar
#     Currency Symbol: $
#
#
# Country: Belarus
# Currencies:
#   - Currency Code: BYN
#     Currency Name: Belarusian ruble
#     Currency Symbol: Br
#
#
# Country: Portugal
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Eswatini
# Currencies:
#   - Currency Code: SZL
#     Currency Name: Swazi lilangeni
#     Currency Symbol: L
#   - Currency Code: ZAR
#     Currency Name: South African rand
#     Currency Symbol: R
#
#
# Country: Poland
# Currencies:
#   - Currency Code: PLN
#     Currency Name: Polish złoty
#     Currency Symbol: zł
#
#
# Country: Switzerland
# Currencies:
#   - Currency Code: CHF
#     Currency Name: Swiss franc
#     Currency Symbol: Fr.
#
#
# Country: Republic of the Congo
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Venezuela
# Currencies:
#   - Currency Code: VES
#     Currency Name: Venezuelan bolívar soberano
#     Currency Symbol: Bs.S.
#
#
# Country: Panama
# Currencies:
#   - Currency Code: PAB
#     Currency Name: Panamanian balboa
#     Currency Symbol: B/.
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Netherlands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Samoa
# Currencies:
#   - Currency Code: WST
#     Currency Name: Samoan tālā
#     Currency Symbol: T
#
#
# Country: Denmark
# Currencies:
#   - Currency Code: DKK
#     Currency Name: Danish krone
#     Currency Symbol: kr
#
#
# Country: Luxembourg
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Faroe Islands
# Currencies:
#   - Currency Code: DKK
#     Currency Name: Danish krone
#     Currency Symbol: kr
#   - Currency Code: FOK
#     Currency Name: Faroese króna
#     Currency Symbol: kr
#
#
# Country: Slovenia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Togo
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Thailand
# Currencies:
#   - Currency Code: THB
#     Currency Name: Thai baht
#     Currency Symbol: ฿
#
#
# Country: Wallis and Futuna
# Currencies:
#   - Currency Code: XPF
#     Currency Name: CFP franc
#     Currency Symbol: ₣
#
#
# Country: Bahamas
# Currencies:
#   - Currency Code: BSD
#     Currency Name: Bahamian dollar
#     Currency Symbol: $
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Tonga
# Currencies:
#   - Currency Code: TOP
#     Currency Name: Tongan paʻanga
#     Currency Symbol: T$
#
#
# Country: Greece
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: San Marino
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Réunion
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Vatican City
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Burundi
# Currencies:
#   - Currency Code: BIF
#     Currency Name: Burundian franc
#     Currency Symbol: Fr
#
#
# Country: Bahrain
# Currencies:
#   - Currency Code: BHD
#     Currency Name: Bahraini dinar
#     Currency Symbol: .د.ب
#
#
# Country: Marshall Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Turks and Caicos Islands
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Isle of Man
# Currencies:
#   - Currency Code: GBP
#     Currency Name: British pound
#     Currency Symbol: £
#   - Currency Code: IMP
#     Currency Name: Manx pound
#     Currency Symbol: £
#
#
# Country: Haiti
# Currencies:
#   - Currency Code: HTG
#     Currency Name: Haitian gourde
#     Currency Symbol: G
#
#
# Country: Afghanistan
# Currencies:
#   - Currency Code: AFN
#     Currency Name: Afghan afghani
#     Currency Symbol: ؋
#
#
# Country: Israel
# Currencies:
#   - Currency Code: ILS
#     Currency Name: Israeli new shekel
#     Currency Symbol: ₪
#
#
# Country: Libya
# Currencies:
#   - Currency Code: LYD
#     Currency Name: Libyan dinar
#     Currency Symbol: ل.د
#
#
# Country: Uruguay
# Currencies:
#   - Currency Code: UYU
#     Currency Name: Uruguayan peso
#     Currency Symbol: $
#
#
# Country: Norfolk Island
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#
#
# Country: Nicaragua
# Currencies:
#   - Currency Code: NIO
#     Currency Name: Nicaraguan córdoba
#     Currency Symbol: C$
#
#
# Country: Cook Islands
# Currencies:
#   - Currency Code: CKD
#     Currency Name: Cook Islands dollar
#     Currency Symbol: $
#   - Currency Code: NZD
#     Currency Name: New Zealand dollar
#     Currency Symbol: $
#
#
# Country: Laos
# Currencies:
#   - Currency Code: LAK
#     Currency Name: Lao kip
#     Currency Symbol: ₭
#
#
# Country: Christmas Island
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#
#
# Country: Saint Helena, Ascension and Tristan da Cunha
# Currencies:
#   - Currency Code: GBP
#     Currency Name: Pound sterling
#     Currency Symbol: £
#   - Currency Code: SHP
#     Currency Name: Saint Helena pound
#     Currency Symbol: £
#
#
# Country: Anguilla
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Micronesia
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Germany
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Guam
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Kiribati
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#   - Currency Code: KID
#     Currency Name: Kiribati dollar
#     Currency Symbol: $
#
#
# Country: Sint Maarten
# Currencies:
#   - Currency Code: ANG
#     Currency Name: Netherlands Antillean guilder
#     Currency Symbol: ƒ
#
#
# Country: Spain
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Jamaica
# Currencies:
#   - Currency Code: JMD
#     Currency Name: Jamaican dollar
#     Currency Symbol: $
#
#
# Country: Palestine
# Currencies:
#   - Currency Code: EGP
#     Currency Name: Egyptian pound
#     Currency Symbol: E£
#   - Currency Code: ILS
#     Currency Name: Israeli new shekel
#     Currency Symbol: ₪
#   - Currency Code: JOD
#     Currency Name: Jordanian dinar
#     Currency Symbol: JD
#
#
# Country: French Guiana
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Andorra
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Chile
# Currencies:
#   - Currency Code: CLP
#     Currency Name: Chilean peso
#     Currency Symbol: $
#
#
# Country: Lesotho
# Currencies:
#   - Currency Code: LSL
#     Currency Name: Lesotho loti
#     Currency Symbol: L
#   - Currency Code: ZAR
#     Currency Name: South African rand
#     Currency Symbol: R
#
#
# Country: Australia
# Currencies:
#   - Currency Code: AUD
#     Currency Name: Australian dollar
#     Currency Symbol: $
#
#
# Country: Grenada
# Currencies:
#   - Currency Code: XCD
#     Currency Name: Eastern Caribbean dollar
#     Currency Symbol: $
#
#
# Country: Ghana
# Currencies:
#   - Currency Code: GHS
#     Currency Name: Ghanaian cedi
#     Currency Symbol: ₵
#
#
# Country: Seychelles
# Currencies:
#   - Currency Code: SCR
#     Currency Name: Seychellois rupee
#     Currency Symbol: ₨
#
#
# Country: Angola
# Currencies:
#   - Currency Code: AOA
#     Currency Name: Angolan kwanza
#     Currency Symbol: Kz
#
#
# Country: Bermuda
# Currencies:
#   - Currency Code: BMD
#     Currency Name: Bermudian dollar
#     Currency Symbol: $
#
#
# Country: Pakistan
# Currencies:
#   - Currency Code: PKR
#     Currency Name: Pakistani rupee
#     Currency Symbol: ₨
#
#
# Country: Mali
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Saudi Arabia
# Currencies:
#   - Currency Code: SAR
#     Currency Name: Saudi riyal
#     Currency Symbol: ر.س
#
#
# Country: Curaçao
# Currencies:
#   - Currency Code: ANG
#     Currency Name: Netherlands Antillean guilder
#     Currency Symbol: ƒ
#
#
# Country: South Korea
# Currencies:
#   - Currency Code: KRW
#     Currency Name: South Korean won
#     Currency Symbol: ₩
#
#
# Country: Ethiopia
# Currencies:
#   - Currency Code: ETB
#     Currency Name: Ethiopian birr
#     Currency Symbol: Br
#
#
# Country: Guadeloupe
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Bangladesh
# Currencies:
#   - Currency Code: BDT
#     Currency Name: Bangladeshi taka
#     Currency Symbol: ৳
#
#
# Country: New Zealand
# Currencies:
#   - Currency Code: NZD
#     Currency Name: New Zealand dollar
#     Currency Symbol: $
#
#
# Country: Comoros
# Currencies:
#   - Currency Code: KMF
#     Currency Name: Comorian franc
#     Currency Symbol: Fr
#
#
# Country: Belize
# Currencies:
#   - Currency Code: BZD
#     Currency Name: Belize dollar
#     Currency Symbol: $
#
#
# Country: Uganda
# Currencies:
#   - Currency Code: UGX
#     Currency Name: Ugandan shilling
#     Currency Symbol: Sh
#
#
# Country: Singapore
# Currencies:
#   - Currency Code: SGD
#     Currency Name: Singapore dollar
#     Currency Symbol: $
#
#
# Country: Liechtenstein
# Currencies:
#   - Currency Code: CHF
#     Currency Name: Swiss franc
#     Currency Symbol: Fr
#
#
# Country: Hungary
# Currencies:
#   - Currency Code: HUF
#     Currency Name: Hungarian forint
#     Currency Symbol: Ft
#
#
# Country: Iceland
# Currencies:
#   - Currency Code: ISK
#     Currency Name: Icelandic króna
#     Currency Symbol: kr
#
#
# Country: Tajikistan
# Currencies:
#   - Currency Code: TJS
#     Currency Name: Tajikistani somoni
#     Currency Symbol: ЅМ
#
#
# Country: Namibia
# Currencies:
#   - Currency Code: NAD
#     Currency Name: Namibian dollar
#     Currency Symbol: $
#   - Currency Code: ZAR
#     Currency Name: South African rand
#     Currency Symbol: R
#
#
# Country: Timor-Leste
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Egypt
# Currencies:
#   - Currency Code: EGP
#     Currency Name: Egyptian pound
#     Currency Symbol: £
#
#
# Country: Serbia
# Currencies:
#   - Currency Code: RSD
#     Currency Name: Serbian dinar
#     Currency Symbol: дин.
#
#
# Country: Mauritius
# Currencies:
#   - Currency Code: MUR
#     Currency Name: Mauritian rupee
#     Currency Symbol: ₨
#
#
# Country: Macau
# Currencies:
#   - Currency Code: MOP
#     Currency Name: Macanese pataca
#     Currency Symbol: P
#
#
# Country: French Polynesia
# Currencies:
#   - Currency Code: XPF
#     Currency Name: CFP franc
#     Currency Symbol: ₣
#
#
# Country: Maldives
# Currencies:
#   - Currency Code: MVR
#     Currency Name: Maldivian rufiyaa
#     Currency Symbol: .ރ
#
#
# Country: Indonesia
# Currencies:
#   - Currency Code: IDR
#     Currency Name: Indonesian rupiah
#     Currency Symbol: Rp
#
#
# Country: DR Congo
# Currencies:
#   - Currency Code: CDF
#     Currency Name: Congolese franc
#     Currency Symbol: FC
#
#
# Country: Estonia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Vietnam
# Currencies:
#   - Currency Code: VND
#     Currency Name: Vietnamese đồng
#     Currency Symbol: ₫
#
#
# Country: Italy
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Guinea
# Currencies:
#   - Currency Code: GNF
#     Currency Name: Guinean franc
#     Currency Symbol: Fr
#
#
# Country: Chad
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Ecuador
# Currencies:
#   - Currency Code: USD
#     Currency Name: United States dollar
#     Currency Symbol: $
#
#
# Country: Georgia
# Currencies:
#   - Currency Code: GEL
#     Currency Name: lari
#     Currency Symbol: ₾
#
#
# Country: Malawi
# Currencies:
#   - Currency Code: MWK
#     Currency Name: Malawian kwacha
#     Currency Symbol: MK
#
#
# Country: Iraq
# Currencies:
#   - Currency Code: IQD
#     Currency Name: Iraqi dinar
#     Currency Symbol: ع.د
#
#
# Country: Svalbard and Jan Mayen
# Currencies:
#   - Currency Code: NOK
#     Currency Name: krone
#     Currency Symbol: kr
#
#
# Country: Benin
# Currencies:
#   - Currency Code: XOF
#     Currency Name: West African CFA franc
#     Currency Symbol: Fr
#
#
# Country: Japan
# Currencies:
#   - Currency Code: JPY
#     Currency Name: Japanese yen
#     Currency Symbol: ¥
#
#
# Country: Dominican Republic
# Currencies:
#   - Currency Code: DOP
#     Currency Name: Dominican peso
#     Currency Symbol: $
#
#
# Country: Qatar
# Currencies:
#   - Currency Code: QAR
#     Currency Name: Qatari riyal
#     Currency Symbol: ر.ق
#
#
# Country: Gabon
# Currencies:
#   - Currency Code: XAF
#     Currency Name: Central African CFA franc
#     Currency Symbol: Fr

# %%
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    display_country_info(countries_data)
else:
    print("Failed to fetch data.")
import requests

def fetch_countries_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
#Fetching the countries which have DOLLAR as its currency
def display_countries_with_dollar_currency(country_data):
    for country in country_data:
        name = country.get('name', {}).get('common', 'N/A')
        currencies = country.get('currencies', {})
        
        # Checking if the currency is "Dollar"
        if any(currency_code.lower() == 'usd' for currency_code in currencies):
            print(f"Country: {name}")
            print("Currencies:")
            
            for currency_code, currency_info in currencies.items():
                currency_name = currency_info.get('name', 'N/A')
                currency_symbol = currency_info.get('symbol', 'N/A')
                
                print(f"  - Currency Code: {currency_code}")
                print(f"    Currency Name: {currency_name}")
                print(f"    Currency Symbol: {currency_symbol}")
            
            print("\n")

# Example usage
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    display_countries_with_dollar_currency(countries_data)
else:
    print("Failed to fetch data.")
import requests

def fetch_countries_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
#Fetching the countries which have EURO as its currency

def display_countries_with_euro_currency(country_data):
    for country in country_data:
        name = country.get('name', {}).get('common', 'N/A')
        currencies = country.get('currencies', {})
        
        # Check if the currency is "Euro"
        if any(currency_code.lower() == 'eur' for currency_code in currencies):
            print(f"Country: {name}")
            print("Currencies:")
            
            for currency_code, currency_info in currencies.items():
                currency_name = currency_info.get('name', 'N/A')
                currency_symbol = currency_info.get('symbol', 'N/A')
                
                print(f"  - Currency Code: {currency_code}")
                print(f"    Currency Name: {currency_name}")
                print(f"    Currency Symbol: {currency_symbol}")
            
            print("\n")

# Example usage
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    display_countries_with_euro_currency(countries_data)
else:
    print("Failed to fetch data.")

# %%
#Fetching the names of all breweries present in the states of Alaska, Maine and New York
# Example usage
url = "https://restcountries.com/v3.1/all"
countries_data = fetch_countries_data(url)

if countries_data:
    display_countries_with_euro_currency(countries_data)
else:
    print("Failed to fetch data.")
import requests

def fetch_breweries_by_state(url, state):
    try:
        response = requests.get(url, params={'by_state': state})
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

def list_brewery_names_by_states(url, states):
    for state in states:
        print(f"Breweries in {state}:")
        breweries_data = fetch_breweries_by_state(url, state)

        if breweries_data:
            for brewery in breweries_data:
                brewery_name = brewery.get('name', 'N/A')
                print(f"  - {brewery_name}")
        else:
            print("Failed to fetch data.")

        print("\n")

# Example usage
url = "https://api.openbrewerydb.org/breweries"
states_of_interest = ['Alaska', 'Maine', 'New York']
list_brewery_names_by_states(url, states_of_interest)
import requests

def fetch_breweries_by_state(url, state):
    try:
        response = requests.get(url, params={'by_state': state})
        response.raise_for_status()

        # Assuming the response contains JSON data
        json_data = response.json()

        return json_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

def count_breweries_by_states(url, states):
    for state in states:
        breweries_data = fetch_breweries_by_state(url, state)

        if breweries_data:
            brewery_count = len(breweries_data)
            print(f"Number of breweries in {state}: {brewery_count}")
        else:
            print(f"Failed to fetch data for {state}.")

# Example usage
url = "https://api.openbrewerydb.org/breweries"
states_of_interest = ['Alaska', 'Maine', 'New York']
count_breweries_by_states(url, states_of_interest)
# Out:
# Country: Mayotte
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Cyprus
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Ireland
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Croatia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Martinique
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Kosovo
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Austria
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Latvia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Åland Islands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Malta
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Saint Barthélemy
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Monaco
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: France
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Belgium
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Finland
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Slovakia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Lithuania
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Saint Martin
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Montenegro
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: French Southern and Antarctic Lands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Saint Pierre and Miquelon
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Portugal
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Netherlands
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Luxembourg
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Slovenia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Greece
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: San Marino
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Réunion
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Vatican City
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Germany
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Spain
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: French Guiana
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Andorra
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Guadeloupe
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Estonia
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Country: Italy
# Currencies:
#   - Currency Code: EUR
#     Currency Name: Euro
#     Currency Symbol: €
#
#
# Breweries in Alaska:
#   - 49th State Brewing Co
#   - 49th State Brewing Co - Anchorage
#   - Alaskan Brewing Co.
#   - Anchorage Brewing Co
#   - Arkose Brewery
#   - Baleen Brewing Co.
#   - Baranof Island Brewing Co
#   - Barnaby Brewing Company
#   - Bawden Street Brewing Company
#   - Bearpaw River Brewing Co
#   - Bleeding Heart Brewery
#   - Broken Tooth Brewing Co
#   - Cooper Landing Brewing Company
#   - Cynosure Brewing
#   - Denali Brewing Company
#   - Devil's Club Brewing
#   - Faults Brewing
#   - Forbidden Peak Brewery
#   - Gakona Brewing Company
#   - Girdwood Brewing Company
#   - Glacier Brewhouse
#   - Grace Ridge Brewing
#   - Growler Bay Brewing Co
#   - Haines Brewing Co
#   - Harbor Mountain Brewing Co
#   - Homer Brewing Co
#   - HooDoo Brewing Co
#   - Humpy's Great Alaskan Alehouse
#   - Icy Strait Brewery
#   - Inside Passage Brewing Company LLC
#   - Kassik's Brewery
#   - Kenai River Brewing Co
#   - King Street Brewing Co
#   - Klondike Brewing Company
#   - Kodiak Island Brewing Co
#   - Last Frontier Brewing Company
#   - Matanuska Brewing Company - Downtown Brewpub
#   - Matanuska Brewing Company - Eagle River
#   - Matanuska Brewing Company - Midtown Brewpub
#   - Midnight Sun Brewing Co
#   - Midnite Mine Brewpub
#   - Odd Man Rush
#   - Onsite Brewing Company
#   - QUAKE! Brewing Company
#   - Resolution Brewing Company
#   - RoughWoods Inn
#   - Seward Brewing
#   - Silver Gulch Brewing Co
#   - Skagway Brewing Co
#   - St Elias Brewing Co
#
#
# Breweries in Maine:
#   - 2 Feet Brewing Company
#   - Airline Brewing Company
#   - Allagash Brewing Co
#   - Andrews Brewing Co
#   - Atlantic Brewing Co
#   - Atlantic Brewing Co / Bar Harbor Brewing
#   - Austin Street Brewery
#   - Bag and Kettle, The
#   - Banded Brewing Company
#   - Bangor Beer Co.
#   - Barreled Souls Brewing Company LLC
#   - Bath Brewing Company
#   - Battery Steele Brewing
#   - Baxter Brewing Co, LLC
#   - Bear Bones Beer
#   - Bear Bones Beer
#   - Belfast Bay Brewing Co
#   - Bigelow Brewing Company
#   - Bissell Brothers Brewing
#   - Black Bear Brewery
#   - Blank Canvas Brewery
#   - Boothbay Craft Brewery, Inc
#   - Bunker Brewing Co
#   - Cushnoc Brewing Company
#   - D.L. Geary Brewing Co Inc.
#   - DeepWater Brewing Company
#   - Definitive Brewing Company
#   - Dirigo Brewing Co.
#   - Drumming Grouse Brewery, LLC
#   - First Mile Brewing Company
#   - Flight Deck Brewing
#   - Fogtown Brewing Company
#   - Fore River Brewing Company
#   - Foulmouthed Brewing
#   - Foundation Brewing Company
#   - Friars' Brewhouse
#   - Funky Bow Brewery & Beer Company
#   - Gary's Olde Towne Tavern
#   - Geaghan Brothers Brewing Co
#   - Geaghan's Pub & Craft Brewery
#   - Gneiss Brewing
#   - Goodfire Brewing Company
#   - Grateful Grain Brewing Company
#   - Gritty McDuffs - Freeport
#   - Gritty McDuffs - Lewiston/Auburn
#   - Gritty McDuffs - Portland
#   - Gruit Brewing
#   - Hidden Cove Brewing Co
#   - Inn On Peaks Island Brewery, The
#   - Island Dog Brewing
#
#
# Breweries in New York:
#   - 12 Gates Brewing Company
#   - 16 Stone Brewpub
#   - 1940's Brewing Company
#   - 2 Way Brewing Company
#   - 212 Brewing Company
#   - 42 North Brewing Company
#   - 6 Degrees of Separation
#   - 7 Sins Brewery
#   - 8th Ward Brewing Company
#   - Abandon Brewing
#   - Adirondack Pub and Brewery
#   - Adirondack Toboggan Company Microbrewery
#   - Akwesasne Mohawk Casino Resort
#   - Alewife Brewing Company
#   - Alphabet City Brewing Co
#   - Amber Lantern Brewing Company
#   - Andean Brewing
#   - Anheuser-Busch Inc â Baldwinsville
#   - Apex Brewery
#   - Argyle Brewing Company
#   - Arrowood Farms
#   - Artisanal Brew Works
#   - Aurora Ale & Lager
#   - Ausable Brewing Co
#   - B9 Beverages Inc
#   - Bacchus Brewing
#   - Bandwagon Brewery
#   - BarkEater Craft Brewery
#   - Barnshed Brewing
#   - Barrage Brewing Co
#   - Barrier Brewing Co
#   - Battle Hill Brewing Company
#   - Cooperstown Brewing Co
#   - Beer Tree Brew Co
#   - Bellport Brewing Company
#   - Big Alice Brewing Company
#   - Big Ditch Brewing Company
#   - Big Inlet Brewing
#   - Big Slide Brewery
#   - Big Tupper Brewing
#   - Binghamton Brewing Co
#   - Birreria @ Eataly
#   - Black Forest Brew Haus
#   - Blind Bat Brewery LLC, The
#   - Blue Collar Brewery, Inc.
#   - Blue Line Brewery
#   - Blue Point Brewing
#   - Blue Point Brewing Co
#   - Bolton Landing Brewing Co.
#   - Boots Brewing Company, Inc.
#
#
# Number of breweries in Alaska: 50
# Number of breweries in Maine: 50
# Number of breweries in New York: 50
