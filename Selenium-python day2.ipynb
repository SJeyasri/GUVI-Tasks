# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import time
from selenium.webdriver.common.by import By
paths = r"/Users/jeyasri/Desktop/chromedriver.exe"
os.environ["PATH"] += os.pathsep + os.path.dirname(paths)
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.cowin.gov.in/")
driver.maximize_window()
#click on the "FAQ" link to open in a new tab
faq_link = driver.find_element(By.LINK_TEXT, "FAQ")
faq_link.click()

# click on the "Partners" link to open in a new tab
partners_link = driver.find_element(By.LINK_TEXT, "Partners")
partners_link.click()

# Switch to the new tabs
driver.switch_to.window(driver.window_handles[1])  
driver.switch_to.window(driver.window_handles[2])

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import time
from selenium.webdriver.common.by import By
paths = r"/Users/jeyasri/Desktop/chromedriver.exe"
os.environ["PATH"] += os.pathsep + os.path.dirname(paths)
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.cowin.gov.in/")
driver.maximize_window()
#click on the "FAQ" link to open in a new tab
faq_link = driver.find_element(By.LINK_TEXT, "FAQ")
faq_link.click()

# click on the "Partners" link to open in a new tab
partners_link = driver.find_element(By.LINK_TEXT, "Partners")
partners_link.click()

# Wait for a few seconds to let the new tabs load
time.sleep(10)

# Fetch and display the IDs of the opened windows
window_ids = driver.window_handles
for idx, window_id in enumerate(window_ids, start=1):
    print(f"Window {idx} ID: {window_id}")

# %%
for window_id in driver.window_handles[1:]:
    driver.switch_to.window(window_id)
    driver.close()

# Switch back to the main window
driver.switch_to.window(driver.window_handles[0])

# Navigate back to the home page
driver.get("https://www.cowin.gov.in/")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import time
from selenium.webdriver.common.by import By
paths = r"/Users/jeyasri/Desktop/chromedriver.exe"
os.environ["PATH"] += os.pathsep + os.path.dirname(paths)
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://labour.gov.in/")

Doc_link = driver.find_element(By.LINK_TEXT, "Documents")
Doc_link.click()

# Find and click on the link for the monthly progress report
monthly_report_link = driver.find_element(By.LINK_TEXT,"Monthly Progress Report")
monthly_report_link.click()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import time
from selenium.webdriver.common.by import By
paths = r"/Users/jeyasri/Desktop/chromedriver.exe"
os.environ["PATH"] += os.pathsep + os.path.dirname(paths)
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://labour.gov.in/")

#Find the "Media" menu
media_link = driver.find_element(By.LINK_TEXT, "Media")
media_link.click()

#find sub menu "Press Releases"
sub_media_link = driver.find_element(By.LINK_TEXT, "Photo Gallery")
sub_media_link.click()

# Wait for the page to load
wait = WebDriverWait(driver, 10)
wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'page-header')))

# Find all image elements in the gallery
image_elements = driver.find_elements_by_xpath("//img[contains(@src, '/sites/default/files/')]")

# Create a folder to store the downloaded images
folder_path = 'downloaded_images'
if not os.path.exists("Users/jeyasri/Desktop/GUVI/pycharmProjects/selenium - python day2/Python - Selenium/downloaded_images"):
    os.makedirs("Users/jeyasri/Desktop/GUVI/pycharmProjects/selenium - python day2/Python - Selenium/downloaded_images")
